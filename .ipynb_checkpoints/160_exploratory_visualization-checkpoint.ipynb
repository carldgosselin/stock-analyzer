# %% [markdown]
# ## Exploratory visualization

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 

# symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  
# note:  SPY will be added in get_data()
# new symbols -> RY (rbc), TM (Toyota)

def plot_selected_normalize(df, columns, start_index, end_index):   
    # Normalize stock prices
    df = normalize_data(df)
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))

def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')
    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])
    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

def test_run():
    # Define a date range
    # dates = pd.date_range('2014-08-01', '2016-08-01')
    dates = pd.date_range('2012-07-13', '2017-07-14')
    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    # Get stock data
    df = get_data(symbols, dates)
    # Normalize and plot
    df = normalize_data(df)
    # plot_selected_normalize(df, ['SPY','UPRO'], '2014-09-26', '2016-12-18')
    plot_selected_normalize(df, ['SPY','UPRO'], '2012-07-13', '2017-07-14')
    
if __name__ == "__main__":
    test_run()

# %%
def plot_selected_normalize(df, columns, start_index, end_index):   
    # Normalize stock prices
    df = normalize_data(df)
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))

def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')
    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])
    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

def test_run():
    # Define a date range
    # dates = pd.date_range('2014-08-01', '2016-08-01')
    dates = pd.date_range('2015-01-22', '2017-01-22')
    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD', 'SPXU']  # SPY will be added in get_data()
    # Get stock data
    df = get_data(symbols, dates)
    # Normalize and plot
    df = normalize_data(df)
    # plot_selected_normalize(df, ['SPY','UPRO'], '2014-09-26', '2016-12-18')
    plot_selected_normalize(df, ['SPY','SPXU'], '2015-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()
# Out:
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/ops.py:929: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 1 but corresponding boolean dimension is 504
#   yrav = yrav[mask]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2176bc497e45> in <module>()
#      46
#      47 if __name__ == "__main__":
# ---> 48     test_run()
#
# <ipython-input-2-2176bc497e45> in test_run()
#      41     df = get_data(symbols, dates)
#      42     # Normalize and plot
# ---> 43     df = normalize_data(df)
#      44     # plot_selected_normalize(df, ['SPY','UPRO'], '2014-09-26', '2016-12-18')
#      45     plot_selected_normalize(df, ['SPY','SPXU'], '2015-01-22', '2017-01-22')
#
# <ipython-input-2-2176bc497e45> in normalize_data(df)
#      23
#      24 def normalize_data(df):
# ---> 25     return df/ df.ix[0,:]
#      26
#      27 def plot_data(df, title="Stock prices"):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in f(self, other, axis, level, fill_value)
#     993             return self._combine_frame(other, na_op, fill_value, level)
#     994         elif isinstance(other, pd.Series):
# --> 995             return self._combine_series(other, na_op, fill_value, axis, level)
#     996         elif isinstance(other, (list, tuple)):
#     997             if axis is not None and self._get_axis_name(axis) == 'index':
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series(self, other, func, fill_value, axis, level)
#    3386             else:
#    3387                 return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
# -> 3388         return self._combine_series_infer(other, func, level=level, fill_value=fill_value)
#    3389
#    3390     def _combine_series_infer(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series_infer(self, other, func, level, fill_value)
#    3397                                      columns=self.columns)
#    3398
# -> 3399         return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
#    3400
#    3401     def _combine_match_index(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_match_columns(self, other, func, level, fill_value)
#    3415
#    3416         new_data = left._data.eval(
# -> 3417             func=func, other=right, axes=[left.columns, self.index])
#    3418         return self._constructor(new_data)
#    3419
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, **kwargs)
#    2729
#    2730     def eval(self, **kwargs):
# -> 2731         return self.apply('eval', **kwargs)
#    2732
#    2733     def setitem(self, **kwargs):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2708                                                  copy=align_copy)
#    2709
# -> 2710             applied = getattr(b, f)(**kwargs)
#    2711
#    2712             if isinstance(applied, list):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, func, other, raise_on_error, try_cast)
#    1052             raise
#    1053         except Exception as detail:
# -> 1054             result = handle_error()
#    1055
#    1056         # technically a broadcast error in numpy can 'work' by returning a
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in handle_error()
#    1036             if raise_on_error:
#    1037                 raise TypeError('Could not operate %s with block values %s'
# -> 1038                                 % (repr(other), str(detail)))
#    1039             else:
#    1040                 # return the values
#
# TypeError: Could not operate array(['null'], dtype=object) with block values index 1 is out of bounds for axis 1 with size 1

# %%
def plot_selected_normalize(df, columns, start_index, end_index):   
    # Normalize stock prices
    df = normalize_data(df)
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))

def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')
    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])
    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

def test_run():
    # Define a date range
    # dates = pd.date_range('2014-08-01', '2016-08-01')
    dates = pd.date_range('2015-01-22', '2017-01-22')
    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD', 'SPXU']  # SPY will be added in get_data()
    # Get stock data
    df = get_data(symbols, dates)
    # Normalize and plot
    df = normalize_data(df)
    # plot_selected_normalize(df, ['SPY','UPRO'], '2014-09-26', '2016-12-18')
    plot_selected_normalize(df, ['UPRO','SPXU'], '2015-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3efa6c8a3d47> in <module>()
#      45
#      46 if __name__ == "__main__":
# ---> 47     test_run()
#
# <ipython-input-3-3efa6c8a3d47> in test_run()
#      40     df = get_data(symbols, dates)
#      41     # Normalize and plot
# ---> 42     df = normalize_data(df)
#      43     # plot_selected_normalize(df, ['SPY','UPRO'], '2014-09-26', '2016-12-18')
#      44     plot_selected_normalize(df, ['UPRO','SPXU'], '2015-01-22', '2017-01-22')
#
# <ipython-input-3-3efa6c8a3d47> in normalize_data(df)
#      22
#      23 def normalize_data(df):
# ---> 24     return df/ df.ix[0,:]
#      25
#      26 def plot_data(df, title="Stock prices"):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in f(self, other, axis, level, fill_value)
#     993             return self._combine_frame(other, na_op, fill_value, level)
#     994         elif isinstance(other, pd.Series):
# --> 995             return self._combine_series(other, na_op, fill_value, axis, level)
#     996         elif isinstance(other, (list, tuple)):
#     997             if axis is not None and self._get_axis_name(axis) == 'index':
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series(self, other, func, fill_value, axis, level)
#    3386             else:
#    3387                 return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
# -> 3388         return self._combine_series_infer(other, func, level=level, fill_value=fill_value)
#    3389
#    3390     def _combine_series_infer(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series_infer(self, other, func, level, fill_value)
#    3397                                      columns=self.columns)
#    3398
# -> 3399         return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
#    3400
#    3401     def _combine_match_index(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_match_columns(self, other, func, level, fill_value)
#    3415
#    3416         new_data = left._data.eval(
# -> 3417             func=func, other=right, axes=[left.columns, self.index])
#    3418         return self._constructor(new_data)
#    3419
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, **kwargs)
#    2729
#    2730     def eval(self, **kwargs):
# -> 2731         return self.apply('eval', **kwargs)
#    2732
#    2733     def setitem(self, **kwargs):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2708                                                  copy=align_copy)
#    2709
# -> 2710             applied = getattr(b, f)(**kwargs)
#    2711
#    2712             if isinstance(applied, list):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, func, other, raise_on_error, try_cast)
#    1052             raise
#    1053         except Exception as detail:
# -> 1054             result = handle_error()
#    1055
#    1056         # technically a broadcast error in numpy can 'work' by returning a
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in handle_error()
#    1036             if raise_on_error:
#    1037                 raise TypeError('Could not operate %s with block values %s'
# -> 1038                                 % (repr(other), str(detail)))
#    1039             else:
#    1040                 # return the values
#
# TypeError: Could not operate array(['null'], dtype=object) with block values index 1 is out of bounds for axis 1 with size 1

# %%
def plot_selected(df, columns, start_index, end_index):
    plot_data(df.ix[start_index:end_index,columns], title="Selected data showing adjusted close price")
    df = df.ix[start_index: end_index, columns]

def plot_selected_normalize(df, columns, start_index, end_index):
    # Normalize stock prices
    df = normalize_data(df)
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))

def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')
    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])
    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

def test_run():
    # Define a date range
    # dates = pd.date_range('2011-12-18', '2016-12-18')
    dates = pd.date_range('2012-01-22', '2017-01-22')
    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    # Get stock data
    df = get_data(symbols, dates)
    # Normalize and plot
    # plot_selected_normalize(df, ['GOOG','AAPL'], '2011-12-18', '2016-12-18')
    plot_selected_normalize(df, ['GOOG','AAPL'], '2012-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()

# %%
def plot_selected(df, columns, start_index, end_index):
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data showing adjusted close price")
    
    df = df.ix[start_index: end_index, columns]

def plot_selected_normalize(df, columns, start_index, end_index):
    
    # Normalize stock prices
    df = normalize_data(df)
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()


def test_run():
    # Define a date range
    # dates = pd.date_range('2011-12-18', '2016-12-18')
    dates = pd.date_range('2012-01-22', '2017-01-22')

    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # Slice and plot
    # plot_selected(df, ['SPY', 'GOOG'], '2014-08-01', '2016-08-01')
    
    # Normalize and plot
    # plot_selected_normalize(df, ['AAPL','DIS','NFLX','AMZN','TSLA','MSFT'], '2011-12-18', '2016-12-18')
    plot_selected_normalize(df, ['AAPL','DIS','NFLX','AMZN','TSLA','MSFT'], '2012-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()

# %%
def plot_selected(df, columns, start_index, end_index):
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data showing adjusted close price")
    
    df = df.ix[start_index: end_index, columns]

def plot_selected_normalize(df, columns, start_index, end_index):
    
    # Normalize stock prices
    df = normalize_data(df)
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()


def test_run():
    # Define a date range
    dates = pd.date_range('2012-05-18', '2017-01-22')

    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # Normalize and plot
    plot_selected_normalize(df, ['AMZN','FB','AXY'], '2012-05-18', '2017-01-22')

if __name__ == "__main__":
    test_run()

# %%
def plot_selected(df, columns, start_index, end_index):
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data showing adjusted close price")
    
    df = df.ix[start_index: end_index, columns]

def plot_selected_normalize(df, columns, start_index, end_index):
    
    # Normalize stock prices
    df = normalize_data(df)
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()


def test_run():
    # Define a date range
    # '2012-05-18', '2017-01-22'
    dates = pd.date_range('2013-05-01', '2017-01-22')

    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # Normalize and plot
    plot_selected_normalize(df, ['SPY','TSLA','GWPH'], '2013-05-01', '2017-01-22')
    
if __name__ == "__main__":
    test_run()

# %%
def plot_selected_normalize(df, columns, start_index, end_index):
    
    # Normalize stock prices
    df = normalize_data(df)
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()


def test_run():
    # Define a date range
    dates = pd.date_range('2012-01-22', '2017-01-22')

    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD']  # SPY will be added in get_data()
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # Normalize and plot
    plot_selected_normalize(df, ['GLD','VIX'], '2012-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()

# %%
def plot_selected_normalize(df, columns, start_index, end_index):
    
    # Normalize stock prices
    df = normalize_data(df)
    
    plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
    
    df = df.ix[start_index: end_index, columns]

def symbol_to_path(symbol, base_dir="data"):
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df

def normalize_data(df):
    return df/ df.ix[0,:]

def plot_data(df, title="Stock prices"):
    ax = df.plot(title=title, fontsize=12,figsize=(12,10))
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()


def test_run():
    # Define a date range
    dates = pd.date_range('2012-01-22', '2017-01-22')

    # Choose stock symbols to read
    symbols = ['UPRO','GOOG','AAPL','AMZN','DIS','NFLX','FB','AXY','VIX','TSLA','GWPH','MSFT','GLD', 'RY', 'TM']  
    # note:  SPY will be added in get_data()
    # new symbols -> RY (rbc), TM (Toyota)
    
    # Get stock data
    df = get_data(symbols, dates)
    
    # Normalize and plot
    plot_selected_normalize(df, ['SPY','VIX', 'RY', 'TM'], '2012-01-22', '2017-01-22')
    
if __name__ == "__main__":
    test_run()
# Out:
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/ops.py:929: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 1 but corresponding boolean dimension is 1258
#   yrav = yrav[mask]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-bc378ca2530d> in <module>()
#      54
#      55 if __name__ == "__main__":
# ---> 56     test_run()
#
# <ipython-input-9-bc378ca2530d> in test_run()
#      51
#      52     # Normalize and plot
# ---> 53     plot_selected_normalize(df, ['SPY','VIX', 'RY', 'TM'], '2012-01-22', '2017-01-22')
#      54
#      55 if __name__ == "__main__":
#
# <ipython-input-9-bc378ca2530d> in plot_selected_normalize(df, columns, start_index, end_index)
#       2
#       3     # Normalize stock prices
# ----> 4     df = normalize_data(df)
#       5
#       6     plot_data(df.ix[start_index:end_index,columns], title="Selected data normalized")
#
# <ipython-input-9-bc378ca2530d> in normalize_data(df)
#      28
#      29 def normalize_data(df):
# ---> 30     return df/ df.ix[0,:]
#      31
#      32 def plot_data(df, title="Stock prices"):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in f(self, other, axis, level, fill_value)
#     993             return self._combine_frame(other, na_op, fill_value, level)
#     994         elif isinstance(other, pd.Series):
# --> 995             return self._combine_series(other, na_op, fill_value, axis, level)
#     996         elif isinstance(other, (list, tuple)):
#     997             if axis is not None and self._get_axis_name(axis) == 'index':
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series(self, other, func, fill_value, axis, level)
#    3386             else:
#    3387                 return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
# -> 3388         return self._combine_series_infer(other, func, level=level, fill_value=fill_value)
#    3389
#    3390     def _combine_series_infer(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_series_infer(self, other, func, level, fill_value)
#    3397                                      columns=self.columns)
#    3398
# -> 3399         return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
#    3400
#    3401     def _combine_match_index(self, other, func, level=None, fill_value=None):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_match_columns(self, other, func, level, fill_value)
#    3415
#    3416         new_data = left._data.eval(
# -> 3417             func=func, other=right, axes=[left.columns, self.index])
#    3418         return self._constructor(new_data)
#    3419
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, **kwargs)
#    2729
#    2730     def eval(self, **kwargs):
# -> 2731         return self.apply('eval', **kwargs)
#    2732
#    2733     def setitem(self, **kwargs):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2708                                                  copy=align_copy)
#    2709
# -> 2710             applied = getattr(b, f)(**kwargs)
#    2711
#    2712             if isinstance(applied, list):
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, func, other, raise_on_error, try_cast)
#    1052             raise
#    1053         except Exception as detail:
# -> 1054             result = handle_error()
#    1055
#    1056         # technically a broadcast error in numpy can 'work' by returning a
#
# /Users/carldgosselin/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in handle_error()
#    1036             if raise_on_error:
#    1037                 raise TypeError('Could not operate %s with block values %s'
# -> 1038                                 % (repr(other), str(detail)))
#    1039             else:
#    1040                 # return the values
#
# TypeError: Could not operate array(['54.389999'], dtype=object) with block values index 1 is out of bounds for axis 1 with size 1
